# %%
import os

def main():
    try:
        # Get the input filename from the user
        filename = input("Enter a class file to grade (i.e. class1 for class1.txt): ")
        
        # Check if the file exists
        if os.path.exists(f"{filename}.txt"):
            print(f"Successfully opened {filename}.txt")
        else:
            print("File cannot be found.")
        
    except KeyboardInterrupt:
        print("\nOperation aborted by the user.")

if __name__ == "__main__":
    main()
# Out:
# Enter a class file to grade (i.e. class1 for class1.txt): class3
# Successfully opened class3.txt

# %%
def is_valid_student_id(student_id):
    """
    Check if a student ID is valid.

    Args:
        student_id (str): The student ID to be checked.

    Returns:
        bool: True if the student ID is valid, False otherwise.
    """
    return len(student_id) == 9 and student_id[0] == 'N' and student_id[1:].isdigit()

def is_valid_answer(answer):
    """
    Check if an answer is valid.

    Args:
        answer (str): The answer to be checked.

    Returns:
        bool: True if the answer is valid, False otherwise.
    """
    return len(answer) == 1 and answer.isalpha()

def analyze_file(file_path):
    """
    Analyze a file containing student data and print a report.

    Args:
        file_path (str): The path to the input file.

    Returns:
        None
    """
    total_valid_lines = 0
    total_invalid_lines = 0

    try:
        with open(file_path, 'r') as file:
            print("Successfully opened", file_path)
            print("**** ANALYZING ****")
            for line_number, line in enumerate(file, start=1):
                line = line.strip()
                data = line.split(',')
                if len(data) == 26:
                    student_id = data[0]
                    if is_valid_student_id(student_id):
                        valid_answers = [answer for answer in data[1:] if is_valid_answer(answer)]
                        if len(valid_answers) == 25:
                            total_valid_lines += 1
                        else:
                            total_invalid_lines += 1
                            print("Invalid line of data:", line_number, "- N# is valid but answers are incomplete")
                    else:
                        total_invalid_lines += 1
                        print("Invalid line of data:", line_number, "- N# is invalid")
                else:
                    total_invalid_lines += 1
                    print("Invalid line of data:", line_number, "- does not contain exactly 26 values:", line)
            print("**** REPORT ****")
            print("Total valid lines of data:", total_valid_lines)
            print("Total invalid lines of data:", total_invalid_lines)
    except FileNotFoundError:
        print("File cannot be found.")

if __name__ == "__main__":
    filename = input("Enter a class to grade (i.e. class1 for class1.txt): ")
    file_path = filename + ".txt"
    analyze_file(file_path)
# Out:
# Enter a class to grade (i.e. class1 for class1.txt): class4
# Successfully opened class4.txt
# **** ANALYZING ****
# Invalid line of data: 1 - N# is valid but answers are incomplete
# Invalid line of data: 2 - N# is valid but answers are incomplete
# Invalid line of data: 4 - N# is valid but answers are incomplete
# Invalid line of data: 5 - N# is valid but answers are incomplete
# Invalid line of data: 6 - N# is valid but answers are incomplete
# Invalid line of data: 7 - N# is valid but answers are incomplete
# Invalid line of data: 8 - N# is valid but answers are incomplete
# Invalid line of data: 9 - N# is valid but answers are incomplete
# Invalid line of data: 10 - N# is valid but answers are incomplete
# Invalid line of data: 11 - N# is valid but answers are incomplete
# Invalid line of data: 12 - N# is valid but answers are incomplete
# Invalid line of data: 13 - N# is valid but answers are incomplete
# Invalid line of data: 14 - N# is valid but answers are incomplete
# Invalid line of data: 15 - N# is valid but answers are incomplete
# Invalid line of data: 16 - N# is valid but answers are incomplete
# Invalid line of data: 17 - N# is valid but answers are incomplete
# Invalid line of data: 18 - N# is valid but answers are incomplete
# Invalid line of data: 19 - N# is valid but answers are incomplete
# Invalid line of data: 20 - N# is valid but answers are incomplete
# Invalid line of data: 21 - N# is valid but answers are incomplete
# Invalid line of data: 22 - N# is valid but answers are incomplete
# Invalid line of data: 23 - N# is valid but answers are incomplete
# Invalid line of data: 24 - N# is valid but answers are incomplete
# Invalid line of data: 25 - N# is valid but answers are incomplete
# Invalid line of data: 26 - N# is valid but answers are incomplete
# Invalid line of data: 27 - N# is valid but answers are incomplete
# Invalid line of data: 28 - N# is valid but answers are incomplete
# Invalid line of data: 29 - N# is valid but answers are incomplete
# Invalid line of data: 30 - N# is valid but answers are incomplete
# Invalid line of data: 31 - N# is valid but answers are incomplete
# Invalid line of data: 32 - N# is valid but answers are incomplete
# Invalid line of data: 33 - N# is valid but answers are incomplete
# Invalid line of data: 34 - N# is valid but answers are incomplete
# Invalid line of data: 35 - N# is valid but answers are incomplete
# Invalid line of data: 36 - N# is valid but answers are incomplete
# Invalid line of data: 37 - N# is valid but answers are incomplete
# Invalid line of data: 38 - N# is valid but answers are incomplete
# Invalid line of data: 39 - N# is valid but answers are incomplete
# Invalid line of data: 40 - N# is valid but answers are incomplete
# Invalid line of data: 41 - N# is valid but answers are incomplete
# Invalid line of data: 42 - N# is valid but answers are incomplete
# Invalid line of data: 43 - N# is valid but answers are incomplete
# Invalid line of data: 44 - N# is valid but answers are incomplete
# Invalid line of data: 45 - N# is valid but answers are incomplete
# Invalid line of data: 46 - N# is valid but answers are incomplete
# Invalid line of data: 47 - N# is valid but answers are incomplete
# Invalid line of data: 48 - N# is valid but answers are incomplete
# Invalid line of data: 49 - N# is valid but answers are incomplete
# Invalid line of data: 50 - N# is valid but answers are incomplete
# Invalid line of data: 51 - N# is valid but answers are incomplete
# Invalid line of data: 52 - N# is valid but answers are incomplete
# Invalid line of data: 53 - N# is valid but answers are incomplete
# Invalid line of data: 54 - N# is valid but answers are incomplete
# Invalid line of data: 55 - N# is valid but answers are incomplete
# Invalid line of data: 56 - N# is valid but answers are incomplete
# Invalid line of data: 58 - N# is valid but answers are incomplete
# Invalid line of data: 59 - N# is valid but answers are incomplete
# Invalid line of data: 60 - N# is valid but answers are incomplete
# Invalid line of data: 61 - N# is valid but answers are incomplete
# Invalid line of data: 62 - N# is valid but answers are incomplete
# Invalid line of data: 63 - N# is valid but answers are incomplete
# Invalid line of data: 64 - N# is valid but answers are incomplete
# Invalid line of data: 65 - N# is valid but answers are incomplete
# Invalid line of data: 66 - N# is valid but answers are incomplete
# Invalid line of data: 67 - N# is valid but answers are incomplete
# Invalid line of data: 68 - N# is valid but answers are incomplete
# Invalid line of data: 69 - N# is valid but answers are incomplete
# Invalid line of data: 70 - N# is valid but answers are incomplete
# Invalid line of data: 71 - N# is valid but answers are incomplete
# Invalid line of data: 72 - N# is valid but answers are incomplete
# Invalid line of data: 73 - N# is valid but answers are incomplete
# Invalid line of data: 74 - N# is valid but answers are incomplete
# Invalid line of data: 75 - N# is valid but answers are incomplete
# Invalid line of data: 76 - N# is valid but answers are incomplete
# Invalid line of data: 77 - N# is valid but answers are incomplete
# Invalid line of data: 78 - N# is valid but answers are incomplete
# Invalid line of data: 79 - N# is valid but answers are incomplete
# Invalid line of data: 80 - N# is valid but answers are incomplete
# Invalid line of data: 81 - N# is valid but answers are incomplete
# Invalid line of data: 82 - N# is valid but answers are incomplete
# Invalid line of data: 83 - N# is valid but answers are incomplete
# Invalid line of data: 84 - N# is valid but answers are incomplete
# Invalid line of data: 86 - N# is valid but answers are incomplete
# Invalid line of data: 87 - N# is valid but answers are incomplete
# Invalid line of data: 89 - N# is valid but answers are incomplete
# Invalid line of data: 90 - N# is valid but answers are incomplete
# Invalid line of data: 91 - N# is valid but answers are incomplete
# Invalid line of data: 92 - N# is valid but answers are incomplete
# Invalid line of data: 93 - N# is valid but answers are incomplete
# Invalid line of data: 94 - N# is valid but answers are incomplete
# Invalid line of data: 95 - N# is valid but answers are incomplete
# Invalid line of data: 96 - N# is valid but answers are incomplete
# Invalid line of data: 97 - N# is valid but answers are incomplete
# Invalid line of data: 98 - N# is valid but answers are incomplete
# Invalid line of data: 99 - N# is valid but answers are incomplete
# Invalid line of data: 101 - N# is valid but answers are incomplete
# Invalid line of data: 102 - N# is valid but answers are incomplete
# Invalid line of data: 103 - N# is valid but answers are incomplete
# Invalid line of data: 104 - N# is valid but answers are incomplete
# Invalid line of data: 105 - N# is valid but answers are incomplete
# Invalid line of data: 107 - N# is valid but answers are incomplete
# Invalid line of data: 108 - N# is valid but answers are incomplete
# Invalid line of data: 109 - N# is valid but answers are incomplete
# Invalid line of data: 110 - N# is valid but answers are incomplete
# Invalid line of data: 111 - N# is valid but answers are incomplete
# Invalid line of data: 112 - N# is valid but answers are incomplete
# Invalid line of data: 113 - N# is valid but answers are incomplete
# Invalid line of data: 114 - N# is valid but answers are incomplete
# Invalid line of data: 115 - N# is valid but answers are incomplete
# Invalid line of data: 116 - N# is valid but answers are incomplete
# Invalid line of data: 118 - N# is valid but answers are incomplete
# Invalid line of data: 119 - N# is valid but answers are incomplete
# Invalid line of data: 122 - N# is valid but answers are incomplete
# Invalid line of data: 123 - N# is valid but answers are incomplete
# Invalid line of data: 124 - N# is valid but answers are incomplete
# Invalid line of data: 125 - N# is valid but answers are incomplete
# Invalid line of data: 126 - N# is valid but answers are incomplete
# Invalid line of data: 127 - N# is valid but answers are incomplete
# Invalid line of data: 128 - N# is valid but answers are incomplete
# Invalid line of data: 129 - N# is valid but answers are incomplete
# Invalid line of data: 130 - N# is valid but answers are incomplete
# Invalid line of data: 131 - N# is valid but answers are incomplete
# Invalid line of data: 132 - N# is valid but answers are incomplete
# Invalid line of data: 133 - N# is valid but answers are incomplete
# Invalid line of data: 134 - N# is valid but answers are incomplete
# Invalid line of data: 135 - N# is valid but answers are incomplete
# Invalid line of data: 136 - N# is valid but answers are incomplete
# Invalid line of data: 137 - N# is valid but answers are incomplete
# Invalid line of data: 139 - N# is valid but answers are incomplete
# Invalid line of data: 140 - N# is valid but answers are incomplete
# Invalid line of data: 141 - N# is valid but answers are incomplete
# Invalid line of data: 142 - N# is valid but answers are incomplete
# Invalid line of data: 143 - N# is valid but answers are incomplete
# Invalid line of data: 144 - N# is valid but answers are incomplete
# Invalid line of data: 145 - N# is valid but answers are incomplete
# Invalid line of data: 146 - N# is valid but answers are incomplete
# Invalid line of data: 147 - N# is valid but answers are incomplete
# Invalid line of data: 148 - N# is valid but answers are incomplete
# Invalid line of data: 149 - N# is valid but answers are incomplete
# Invalid line of data: 150 - N# is valid but answers are incomplete
# Invalid line of data: 151 - N# is valid but answers are incomplete
# Invalid line of data: 152 - N# is valid but answers are incomplete
# Invalid line of data: 153 - N# is valid but answers are incomplete
# Invalid line of data: 154 - N# is valid but answers are incomplete
# Invalid line of data: 155 - N# is valid but answers are incomplete
# Invalid line of data: 156 - N# is valid but answers are incomplete
# Invalid line of data: 157 - N# is valid but answers are incomplete
# Invalid line of data: 158 - N# is valid but answers are incomplete
# Invalid line of data: 159 - N# is valid but answers are incomplete
# Invalid line of data: 160 - N# is valid but answers are incomplete
# Invalid line of data: 161 - N# is valid but answers are incomplete
# Invalid line of data: 162 - N# is valid but answers are incomplete
# Invalid line of data: 163 - N# is valid but answers are incomplete
# Invalid line of data: 164 - N# is valid but answers are incomplete
# Invalid line of data: 166 - N# is valid but answers are incomplete
# Invalid line of data: 168 - N# is valid but answers are incomplete
# Invalid line of data: 169 - N# is valid but answers are incomplete
# Invalid line of data: 170 - N# is valid but answers are incomplete
# Invalid line of data: 172 - N# is valid but answers are incomplete
# Invalid line of data: 173 - N# is valid but answers are incomplete
# Invalid line of data: 174 - N# is valid but answers are incomplete
# Invalid line of data: 175 - N# is valid but answers are incomplete
# Invalid line of data: 176 - N# is valid but answers are incomplete
# Invalid line of data: 177 - N# is valid but answers are incomplete
# Invalid line of data: 178 - N# is valid but answers are incomplete
# Invalid line of data: 179 - N# is valid but answers are incomplete
# Invalid line of data: 180 - N# is valid but answers are incomplete
# Invalid line of data: 181 - N# is valid but answers are incomplete
# Invalid line of data: 182 - N# is valid but answers are incomplete
# Invalid line of data: 183 - N# is valid but answers are incomplete
# Invalid line of data: 184 - N# is valid but answers are incomplete
# Invalid line of data: 185 - N# is valid but answers are incomplete
# Invalid line of data: 186 - N# is valid but answers are incomplete
# Invalid line of data: 187 - N# is valid but answers are incomplete
# Invalid line of data: 188 - N# is valid but answers are incomplete
# Invalid line of data: 189 - N# is valid but answers are incomplete
# Invalid line of data: 190 - N# is valid but answers are incomplete
# Invalid line of data: 191 - N# is valid but answers are incomplete
# Invalid line of data: 192 - N# is valid but answers are incomplete
# Invalid line of data: 193 - N# is valid but answers are incomplete
# Invalid line of data: 194 - N# is valid but answers are incomplete
# Invalid line of data: 196 - N# is valid but answers are incomplete
# Invalid line of data: 197 - N# is valid but answers are incomplete
# Invalid line of data: 198 - N# is valid but answers are incomplete
# Invalid line of data: 199 - N# is valid but answers are incomplete
# Invalid line of data: 200 - N# is valid but answers are incomplete
# Invalid line of data: 201 - N# is valid but answers are incomplete
# Invalid line of data: 202 - N# is valid but answers are incomplete
# Invalid line of data: 203 - N# is valid but answers are incomplete
# Invalid line of data: 204 - N# is valid but answers are incomplete
# Invalid line of data: 205 - N# is valid but answers are incomplete
# Invalid line of data: 206 - N# is valid but answers are incomplete
# Invalid line of data: 207 - N# is valid but answers are incomplete
# Invalid line of data: 208 - N# is valid but answers are incomplete
# Invalid line of data: 209 - N# is valid but answers are incomplete
# Invalid line of data: 210 - N# is valid but answers are incomplete
# Invalid line of data: 211 - N# is valid but answers are incomplete
# Invalid line of data: 213 - N# is valid but answers are incomplete
# Invalid line of data: 214 - N# is valid but answers are incomplete
# Invalid line of data: 215 - N# is valid but answers are incomplete
# Invalid line of data: 216 - N# is valid but answers are incomplete
# Invalid line of data: 217 - N# is valid but answers are incomplete
# Invalid line of data: 218 - N# is valid but answers are incomplete
# Invalid line of data: 219 - N# is valid but answers are incomplete
# Invalid line of data: 220 - N# is valid but answers are incomplete
# Invalid line of data: 221 - N# is valid but answers are incomplete
# Invalid line of data: 222 - N# is valid but answers are incomplete
# Invalid line of data: 223 - N# is valid but answers are incomplete
# Invalid line of data: 224 - N# is valid but answers are incomplete
# Invalid line of data: 225 - N# is valid but answers are incomplete
# Invalid line of data: 227 - N# is valid but answers are incomplete
# Invalid line of data: 228 - N# is valid but answers are incomplete
# Invalid line of data: 229 - N# is valid but answers are incomplete
# Invalid line of data: 230 - N# is valid but answers are incomplete
# Invalid line of data: 231 - N# is valid but answers are incomplete
# Invalid line of data: 232 - N# is valid but answers are incomplete
# Invalid line of data: 233 - N# is valid but answers are incomplete
# Invalid line of data: 234 - N# is valid but answers are incomplete
# Invalid line of data: 235 - N# is valid but answers are incomplete
# Invalid line of data: 236 - N# is valid but answers are incomplete
# Invalid line of data: 237 - N# is valid but answers are incomplete
# Invalid line of data: 238 - N# is valid but answers are incomplete
# Invalid line of data: 239 - N# is valid but answers are incomplete
# Invalid line of data: 240 - N# is valid but answers are incomplete
# Invalid line of data: 241 - N# is valid but answers are incomplete
# Invalid line of data: 242 - N# is valid but answers are incomplete
# Invalid line of data: 243 - N# is valid but answers are incomplete
# Invalid line of data: 244 - N# is valid but answers are incomplete
# Invalid line of data: 245 - N# is valid but answers are incomplete
# Invalid line of data: 246 - N# is valid but answers are incomplete
# Invalid line of data: 247 - N# is valid but answers are incomplete
# Invalid line of data: 248 - N# is valid but answers are incomplete
# Invalid line of data: 250 - N# is valid but answers are incomplete
# Invalid line of data: 251 - N# is valid but answers are incomplete
# Invalid line of data: 252 - N# is valid but answers are incomplete
# Invalid line of data: 253 - N# is valid but answers are incomplete
# Invalid line of data: 254 - N# is valid but answers are incomplete
# Invalid line of data: 255 - N# is valid but answers are incomplete
# Invalid line of data: 256 - N# is valid but answers are incomplete
# Invalid line of data: 257 - N# is valid but answers are incomplete
# Invalid line of data: 258 - N# is valid but answers are incomplete
# Invalid line of data: 259 - N# is valid but answers are incomplete
# Invalid line of data: 260 - N# is valid but answers are incomplete
# Invalid line of data: 261 - N# is valid but answers are incomplete
# Invalid line of data: 262 - N# is valid but answers are incomplete
# Invalid line of data: 263 - N# is valid but answers are incomplete
# Invalid line of data: 264 - N# is valid but answers are incomplete
# Invalid line of data: 265 - N# is valid but answers are incomplete
# Invalid line of data: 266 - N# is valid but answers are incomplete
# Invalid line of data: 267 - N# is valid but answers are incomplete
# Invalid line of data: 268 - N# is valid but answers are incomplete
# Invalid line of data: 269 - N# is valid but answers are incomplete
# Invalid line of data: 270 - N# is valid but answers are incomplete
# Invalid line of data: 271 - N# is valid but answers are incomplete
# Invalid line of data: 272 - N# is valid but answers are incomplete
# Invalid line of data: 273 - N# is valid but answers are incomplete
# Invalid line of data: 274 - N# is valid but answers are incomplete
# Invalid line of data: 276 - N# is valid but answers are incomplete
# Invalid line of data: 278 - N# is valid but answers are incomplete
# Invalid line of data: 279 - N# is valid but answers are incomplete
# Invalid line of data: 280 - N# is valid but answers are incomplete
# Invalid line of data: 281 - N# is valid but answers are incomplete
# Invalid line of data: 282 - N# is valid but answers are incomplete
# Invalid line of data: 283 - N# is valid but answers are incomplete
# Invalid line of data: 284 - N# is valid but answers are incomplete
# Invalid line of data: 285 - N# is valid but answers are incomplete
# Invalid line of data: 286 - N# is valid but answers are incomplete
# Invalid line of data: 287 - N# is valid but answers are incomplete
# Invalid line of data: 288 - N# is valid but answers are incomplete
# Invalid line of data: 289 - N# is valid but answers are incomplete
# Invalid line of data: 290 - N# is valid but answers are incomplete
# Invalid line of data: 291 - N# is valid but answers are incomplete
# Invalid line of data: 292 - N# is valid but answers are incomplete
# Invalid line of data: 293 - N# is valid but answers are incomplete
# Invalid line of data: 294 - N# is valid but answers are incomplete
# Invalid line of data: 295 - N# is valid but answers are incomplete
# Invalid line of data: 296 - N# is valid but answers are incomplete
# Invalid line of data: 297 - N# is valid but answers are incomplete
# Invalid line of data: 298 - N# is valid but answers are incomplete
# Invalid line of data: 299 - N# is valid but answers are incomplete
# Invalid line of data: 300 - N# is valid but answers are incomplete
# Invalid line of data: 301 - N# is valid but answers are incomplete
# Invalid line of data: 302 - N# is valid but answers are incomplete
# Invalid line of data: 303 - N# is valid but answers are incomplete
# Invalid line of data: 304 - N# is valid but answers are incomplete
# Invalid line of data: 305 - N# is valid but answers are incomplete
# Invalid line of data: 306 - N# is valid but answers are incomplete
# Invalid line of data: 307 - N# is valid but answers are incomplete
# Invalid line of data: 308 - N# is valid but answers are incomplete
# Invalid line of data: 309 - N# is valid but answers are incomplete
# Invalid line of data: 311 - N# is valid but answers are incomplete
# Invalid line of data: 312 - N# is valid but answers are incomplete
# Invalid line of data: 314 - N# is valid but answers are incomplete
# Invalid line of data: 315 - N# is valid but answers are incomplete
# Invalid line of data: 316 - N# is valid but answers are incomplete
# Invalid line of data: 317 - N# is valid but answers are incomplete
# Invalid line of data: 318 - N# is valid but answers are incomplete
# Invalid line of data: 321 - N# is valid but answers are incomplete
# Invalid line of data: 322 - N# is valid but answers are incomplete
# Invalid line of data: 323 - N# is valid but answers are incomplete
# Invalid line of data: 325 - N# is valid but answers are incomplete
# Invalid line of data: 326 - N# is valid but answers are incomplete
# Invalid line of data: 327 - N# is valid but answers are incomplete
# Invalid line of data: 328 - N# is valid but answers are incomplete
# Invalid line of data: 329 - N# is valid but answers are incomplete
# Invalid line of data: 330 - N# is valid but answers are incomplete
# Invalid line of data: 331 - N# is valid but answers are incomplete
# Invalid line of data: 332 - N# is valid but answers are incomplete
# Invalid line of data: 333 - N# is valid but answers are incomplete
# Invalid line of data: 334 - N# is valid but answers are incomplete
# Invalid line of data: 335 - N# is valid but answers are incomplete
# Invalid line of data: 337 - N# is valid but answers are incomplete
# Invalid line of data: 338 - N# is valid but answers are incomplete
# Invalid line of data: 339 - N# is valid but answers are incomplete
# Invalid line of data: 340 - N# is valid but answers are incomplete
# Invalid line of data: 341 - N# is valid but answers are incomplete
# Invalid line of data: 342 - N# is valid but answers are incomplete
# Invalid line of data: 343 - N# is valid but answers are incomplete
# Invalid line of data: 344 - N# is valid but answers are incomplete
# Invalid line of data: 345 - N# is valid but answers are incomplete
# Invalid line of data: 346 - N# is valid but answers are incomplete
# Invalid line of data: 347 - N# is valid but answers are incomplete
# Invalid line of data: 349 - N# is valid but answers are incomplete
# Invalid line of data: 350 - N# is valid but answers are incomplete
# Invalid line of data: 351 - N# is valid but answers are incomplete
# Invalid line of data: 352 - N# is valid but answers are incomplete
# Invalid line of data: 353 - N# is valid but answers are incomplete
# Invalid line of data: 354 - N# is valid but answers are incomplete
# Invalid line of data: 355 - N# is valid but answers are incomplete
# Invalid line of data: 356 - N# is valid but answers are incomplete
# Invalid line of data: 357 - N# is valid but answers are incomplete
# Invalid line of data: 358 - N# is valid but answers are incomplete
# Invalid line of data: 359 - N# is valid but answers are incomplete
# Invalid line of data: 360 - N# is valid but answers are incomplete
# Invalid line of data: 361 - N# is valid but answers are incomplete
# Invalid line of data: 362 - N# is valid but answers are incomplete
# Invalid line of data: 363 - N# is valid but answers are incomplete
# Invalid line of data: 364 - N# is valid but answers are incomplete
# Invalid line of data: 365 - N# is valid but answers are incomplete
# Invalid line of data: 366 - N# is valid but answers are incomplete
# Invalid line of data: 367 - N# is valid but answers are incomplete
# Invalid line of data: 368 - N# is valid but answers are incomplete
# Invalid line of data: 369 - N# is valid but answers are incomplete
# Invalid line of data: 370 - N# is valid but answers are incomplete
# Invalid line of data: 371 - N# is valid but answers are incomplete
# Invalid line of data: 372 - N# is valid but answers are incomplete
# Invalid line of data: 373 - N# is valid but answers are incomplete
# Invalid line of data: 374 - N# is valid but answers are incomplete
# Invalid line of data: 375 - N# is valid but answers are incomplete
# Invalid line of data: 376 - N# is valid but answers are incomplete
# Invalid line of data: 377 - N# is valid but answers are incomplete
# Invalid line of data: 378 - N# is valid but answers are incomplete
# Invalid line of data: 379 - N# is valid but answers are incomplete
# Invalid line of data: 380 - N# is valid but answers are incomplete
# Invalid line of data: 381 - N# is valid but answers are incomplete
# Invalid line of data: 382 - N# is valid but answers are incomplete
# Invalid line of data: 383 - N# is valid but answers are incomplete
# Invalid line of data: 384 - N# is valid but answers are incomplete
# Invalid line of data: 385 - N# is valid but answers are incomplete
# Invalid line of data: 386 - N# is valid but answers are incomplete
# Invalid line of data: 387 - N# is valid but answers are incomplete
# Invalid line of data: 388 - N# is valid but answers are incomplete
# Invalid line of data: 389 - N# is valid but answers are incomplete
# Invalid line of data: 390 - N# is valid but answers are incomplete
# Invalid line of data: 391 - N# is valid but answers are incomplete
# Invalid line of data: 392 - N# is valid but answers are incomplete
# Invalid line of data: 393 - N# is valid but answers are incomplete
# Invalid line of data: 394 - N# is valid but answers are incomplete
# Invalid line of data: 395 - N# is valid but answers are incomplete
# Invalid line of data: 396 - N# is valid but answers are incomplete
# Invalid line of data: 397 - N# is valid but answers are incomplete
# Invalid line of data: 398 - N# is valid but answers are incomplete
# Invalid line of data: 399 - N# is valid but answers are incomplete
# Invalid line of data: 400 - N# is valid but answers are incomplete
# Invalid line of data: 401 - N# is valid but answers are incomplete
# Invalid line of data: 402 - N# is valid but answers are incomplete
# Invalid line of data: 403 - N# is valid but answers are incomplete
# Invalid line of data: 404 - N# is valid but answers are incomplete
# Invalid line of data: 405 - N# is valid but answers are incomplete
# Invalid line of data: 406 - N# is valid but answers are incomplete
# Invalid line of data: 407 - N# is valid but answers are incomplete
# Invalid line of data: 408 - N# is valid but answers are incomplete
# Invalid line of data: 409 - N# is valid but answers are incomplete
# Invalid line of data: 410 - N# is valid but answers are incomplete
# Invalid line of data: 411 - N# is valid but answers are incomplete
# Invalid line of data: 412 - N# is valid but answers are incomplete
# Invalid line of data: 413 - N# is valid but answers are incomplete
# Invalid line of data: 414 - N# is valid but answers are incomplete
# Invalid line of data: 415 - N# is valid but answers are incomplete
# Invalid line of data: 416 - N# is valid but answers are incomplete
# Invalid line of data: 418 - N# is valid but answers are incomplete
# Invalid line of data: 419 - N# is valid but answers are incomplete
# Invalid line of data: 420 - N# is valid but answers are incomplete
# Invalid line of data: 421 - N# is valid but answers are incomplete
# Invalid line of data: 422 - N# is valid but answers are incomplete
# Invalid line of data: 423 - N# is valid but answers are incomplete
# Invalid line of data: 424 - N# is valid but answers are incomplete
# Invalid line of data: 425 - N# is valid but answers are incomplete
# Invalid line of data: 426 - N# is valid but answers are incomplete
# Invalid line of data: 427 - N# is valid but answers are incomplete
# Invalid line of data: 428 - N# is valid but answers are incomplete
# Invalid line of data: 429 - N# is valid but answers are incomplete
# Invalid line of data: 430 - N# is valid but answers are incomplete
# Invalid line of data: 431 - N# is valid but answers are incomplete
# Invalid line of data: 432 - N# is valid but answers are incomplete
# Invalid line of data: 433 - N# is valid but answers are incomplete
# Invalid line of data: 434 - N# is valid but answers are incomplete
# Invalid line of data: 435 - N# is valid but answers are incomplete
# Invalid line of data: 436 - N# is valid but answers are incomplete
# Invalid line of data: 437 - N# is valid but answers are incomplete
# Invalid line of data: 438 - N# is valid but answers are incomplete
# Invalid line of data: 439 - N# is valid but answers are incomplete
# Invalid line of data: 440 - N# is valid but answers are incomplete
# Invalid line of data: 441 - N# is valid but answers are incomplete
# Invalid line of data: 444 - N# is valid but answers are incomplete
# Invalid line of data: 445 - N# is valid but answers are incomplete
# Invalid line of data: 446 - N# is valid but answers are incomplete
# Invalid line of data: 447 - N# is valid but answers are incomplete
# Invalid line of data: 448 - N# is valid but answers are incomplete
# Invalid line of data: 449 - N# is valid but answers are incomplete
# Invalid line of data: 450 - N# is valid but answers are incomplete
# Invalid line of data: 451 - N# is valid but answers are incomplete
# Invalid line of data: 452 - N# is valid but answers are incomplete
# Invalid line of data: 453 - N# is valid but answers are incomplete
# Invalid line of data: 454 - N# is valid but answers are incomplete
# Invalid line of data: 455 - N# is valid but answers are incomplete
# Invalid line of data: 456 - N# is valid but answers are incomplete
# Invalid line of data: 457 - N# is valid but answers are incomplete
# Invalid line of data: 458 - N# is valid but answers are incomplete
# Invalid line of data: 459 - N# is valid but answers are incomplete
# Invalid line of data: 460 - N# is valid but answers are incomplete
# Invalid line of data: 461 - N# is valid but answers are incomplete
# Invalid line of data: 462 - N# is valid but answers are incomplete
# Invalid line of data: 463 - N# is valid but answers are incomplete
# Invalid line of data: 464 - N# is valid but answers are incomplete
# Invalid line of data: 465 - N# is valid but answers are incomplete
# Invalid line of data: 466 - N# is valid but answers are incomplete
# Invalid line of data: 467 - N# is valid but answers are incomplete
# Invalid line of data: 468 - N# is valid but answers are incomplete
# Invalid line of data: 469 - N# is valid but answers are incomplete
# Invalid line of data: 470 - N# is valid but answers are incomplete
# Invalid line of data: 471 - does not contain exactly 26 values: N00000616,B,A,D,D,A,B,D,A,C,C,D,C,A,B,A,C,B,D,A,,A,B,B,D,D,A
# Invalid line of data: 472 - N# is valid but answers are incomplete
# Invalid line of data: 473 - N# is valid but answers are incomplete
# Invalid line of data: 474 - N# is valid but answers are incomplete
# Invalid line of data: 475 - N# is valid but answers are incomplete
# Invalid line of data: 476 - N# is valid but answers are incomplete
# Invalid line of data: 477 - N# is valid but answers are incomplete
# Invalid line of data: 478 - N# is invalid
# Invalid line of data: 479 - N# is valid but answers are incomplete
# Invalid line of data: 480 - N# is valid but answers are incomplete
# Invalid line of data: 481 - N# is valid but answers are incomplete
# Invalid line of data: 482 - N# is valid but answers are incomplete
# Invalid line of data: 483 - N# is valid but answers are incomplete
# Invalid line of data: 484 - N# is valid but answers are incomplete
# Invalid line of data: 485 - N# is valid but answers are incomplete
# Invalid line of data: 486 - N# is valid but answers are incomplete
# Invalid line of data: 487 - N# is valid but answers are incomplete
# Invalid line of data: 488 - N# is valid but answers are incomplete
# Invalid line of data: 489 - N# is valid but answers are incomplete
# Invalid line of data: 490 - N# is valid but answers are incomplete
# Invalid line of data: 491 - N# is valid but answers are incomplete
# Invalid line of data: 492 - N# is invalid
# Invalid line of data: 493 - does not contain exactly 26 values: N00000638,B,A,D,D,C,B,D,A,C,,D,B,A,B,A,B,C,D,A,C,A,,,D,D,Q
# Invalid line of data: 494 - N# is valid but answers are incomplete
# Invalid line of data: 495 - N# is valid but answers are incomplete
# **** REPORT ****
# Total valid lines of data: 29
# Total invalid lines of data: 466

# %%
# Function to calculate the score for a student's answers
def calculate_score(answer_key, student_answers):
    """
    Calculate the score for a student's answers based on an answer key.

    Args:
        answer_key (list): A list of correct answers.
        student_answers (list): A list of student's answers.

    Returns:
        int: The calculated score for the student.
    """
    score = 0
    for key, answer in zip(answer_key, student_answers):
        if answer == key:
            score += 4
        elif answer == '':
            pass
        else:
            score -= 1
    return score

def main():
    answer_key = "B,A,D,D,C,B,D,A,C,C,D,B,A,B,A,C,B,D,A,C,A,A,B,D,D"
    
    # Input the class filename and construct the file path
    filename = input("Enter a class to grade (i.e. class1 for class1.txt): ")
    file_path = filename + ".txt"
    
    valid_scores = []
    question_skip_count = [0] * 25
    question_wrong_count = [0] * 25

    try:
        # Open and analyze the student data file
        with open(file_path, 'r') as file:
            print("Successfully opened", file_path)
            print("**** ANALYZING ****")
            for line in file:
                line = line.strip()
                data = line.split(',')
                if len(data) == 26:
                    student_id = data[0]
                    student_answers = data[1:]
                    if is_valid_student_id(student_id):
                        score = calculate_score(answer_key.split(','), student_answers)
                        valid_scores.append(score)
                        for index, answer in enumerate(student_answers):
                            if answer == '':
                                question_skip_count[index] += 1
                            elif answer != answer_key.split(',')[index]:
                                question_wrong_count[index] += 1

        # Calculate various statistics and print the report
        total_students = len(valid_scores)
        high_scores = sum(score > 80 for score in valid_scores)
        mean_score = round(sum(valid_scores) / total_students, 2)
        highest_score = max(valid_scores)
        lowest_score = min(valid_scores)
        score_range = highest_score - lowest_score
        sorted_scores = sorted(valid_scores)
        median_index = total_students // 2
        median_score = sorted_scores[median_index] if total_students % 2 == 1 else (sorted_scores[median_index - 1] + sorted_scores[median_index]) / 2

        print("**** REPORT ****")
        print("Total valid lines of data:", total_students)
        print("Total student of high scores:", high_scores)
        print("Mean (average) score:", mean_score)
        print("Highest score:", highest_score)
        print("Lowest score:", lowest_score)
        print("Range of scores:", score_range)
        print("Median score:", median_score)

        skip_info = [(index + 1, count, round(count / total_students, 2)) for index, count in enumerate(question_skip_count)]
        skip_info.sort(key=lambda x: x[1], reverse=True)
        print("Question that most people skip:", ', '.join(f"{q[0]} - {q[1]} - {q[2]}" for q in skip_info if q[1] > 0))

        wrong_info = [(index + 1, count, round(count / total_students, 2)) for index, count in enumerate(question_wrong_count)]
        wrong_info.sort(key=lambda x: x[1], reverse=True)
        print("Question that most people answer incorrectly:", ', '.join(f"{q[0]} - {q[1]} - {q[2]}" for q in wrong_info if q[1] > 0))

    except FileNotFoundError:
        print("File cannot be found.")

if __name__ == "__main__":
    main()
# Out:
# Enter a class to grade (i.e. class1 for class1.txt): class7
# Successfully opened class7.txt
# **** ANALYZING ****
# **** REPORT ****
# Total valid lines of data: 193
# Total student of high scores: 59
# Mean (average) score: 74.85
# Highest score: 100
# Lowest score: 47
# Range of scores: 53
# Median score: 75
# Question that most people skip: 4 - 28 - 0.15, 1 - 27 - 0.14, 9 - 25 - 0.13, 11 - 24 - 0.12, 12 - 24 - 0.12, 18 - 23 - 0.12, 25 - 23 - 0.12, 13 - 22 - 0.11, 19 - 22 - 0.11, 2 - 21 - 0.11, 22 - 21 - 0.11, 5 - 20 - 0.1, 6 - 20 - 0.1, 8 - 20 - 0.1, 16 - 20 - 0.1, 20 - 20 - 0.1, 7 - 18 - 0.09, 14 - 18 - 0.09, 15 - 17 - 0.09, 17 - 17 - 0.09, 21 - 16 - 0.08, 23 - 16 - 0.08, 3 - 14 - 0.07, 10 - 13 - 0.07, 24 - 12 - 0.06
# Question that most people answer incorrectly: 7 - 32 - 0.17, 4 - 28 - 0.15, 12 - 28 - 0.15, 17 - 28 - 0.15, 24 - 27 - 0.14, 10 - 26 - 0.13, 21 - 25 - 0.13, 2 - 24 - 0.12, 6 - 24 - 0.12, 9 - 24 - 0.12, 25 - 24 - 0.12, 5 - 23 - 0.12, 15 - 23 - 0.12, 13 - 22 - 0.11, 23 - 22 - 0.11, 3 - 21 - 0.11, 8 - 21 - 0.11, 11 - 21 - 0.11, 16 - 21 - 0.11, 19 - 21 - 0.11, 18 - 19 - 0.1, 22 - 19 - 0.1, 1 - 18 - 0.09, 14 - 16 - 0.08, 20 - 13 - 0.07

# %%
pip install pandas numpy
# Out:
# Requirement already satisfied: pandas in c:\users\user\anaconda3\lib\site-packages (1.5.3)
# Requirement already satisfied: numpy in c:\users\user\anaconda3\lib\site-packages (1.23.5)
# Requirement already satisfied: pytz>=2020.1 in c:\users\user\anaconda3\lib\site-packages (from pandas) (2022.7)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\user\anaconda3\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\user\anaconda3\lib\site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np

# Function to calculate the score for a student's answers
def calculate_score(answer_key, student_answers):
    score = 0
    for i in range(len(answer_key)):
        if student_answers[i] == '':
            continue
        elif student_answers[i] == answer_key[i]:
            score += 4
        else:
            score -= 1
    return score

def main():
    answer_key = "B,A,D,D,C,B,D,A,C,C,D,B,A,B,A,C,B,D,A,C,A,A,B,D,D"
    
    # Get the input filename from the user
    filename = input("Enter a class to grade (i.e. class1 for class1.txt): ")
    file_path = filename + ".txt"
    
    try:
        # Read the student data from the input file using pandas
        df = pd.read_csv(file_path, header=None)
        df.columns = ['Student_ID'] + [f'Q{i+1}' for i in range(25)]

        # Initialize variables to store statistics
        valid_scores = {}
        skipped_questions = [0] * 25
        incorrect_questions = [0] * 25
        
        # Process each student's data
        for index, row in df.iterrows():
            student_id = row['Student_ID']
            student_answers = list(row[1:])
            score = calculate_score(answer_key.split(','), student_answers)
            valid_scores[student_id] = score
            for i, answer in enumerate(student_answers):
                if pd.isna(answer):
                    skipped_questions[i] += 1
                elif answer != answer_key[i]:
                    incorrect_questions[i] += 1
        
        valid_lines = len(df)
        
        # Calculate and display statistics
        high_scores = sum(score > 80 for score in valid_scores.values())
        print(f"Total student of high scores: {high_scores}")
        
        scores = list(valid_scores.values())
        mean_score = np.mean(scores)
        print(f"Mean (average) score: {mean_score:.2f}")
        
        highest_score = max(scores)
        print(f"Highest score: {highest_score}")
        
        lowest_score = min(scores)
        print(f"Lowest score: {lowest_score}")
        
        score_range = highest_score - lowest_score
        print(f"Range of scores: {score_range}")
        
        sorted_scores = np.sort(scores)
        mid = len(sorted_scores) // 2
        if len(sorted_scores) % 2 == 1:
            median_score = sorted_scores[mid]
        else:
            median_score = np.mean([sorted_scores[mid - 1], sorted_scores[mid]])
        print(f"Median score: {median_score}")
        
        max_skipped = max(skipped_questions)
        max_skipped_indices = [str(i + 1) for i, count in enumerate(skipped_questions) if count == max_skipped]
        skipped_percent = [count / valid_lines for count in skipped_questions]
        skipped_info = ', '.join([f"{index} - {max_skipped} - {skipped_percent[i]:.2f}" for i, index in enumerate(max_skipped_indices)])
        print(f"Question that most people skip: {skipped_info}")
        
        max_incorrect = max(incorrect_questions)
        max_incorrect_indices = [str(i + 1) for i, count in enumerate(incorrect_questions) if count == max_incorrect]
        incorrect_percent = [count / valid_lines for count in incorrect_questions]
        incorrect_info = ', '.join([f"{index} - {max_incorrect} - {incorrect_percent[i]:.2f}" for i, index in enumerate(max_incorrect_indices)])
        print(f"Question that most people answer incorrectly: {incorrect_info}")

        # Create a DataFrame for results and save it to a file
        result_df = pd.DataFrame(list(valid_scores.items()), columns=['Student_ID', 'Score'])
        result_df.to_csv(f"{filename}_grades.txt", index=False)
        print(f"Result file '{filename}_grades.txt' created successfully.")

    except FileNotFoundError:
        print("File cannot be found.")

if __name__ == "__main__":
    main()
# Out:
# Enter a class to grade (i.e. class1 for class1.txt): class1
# Total student of high scores: 4
# Mean (average) score: 73.00
# Highest score: 90
# Lowest score: 55
# Range of scores: 35
# Median score: 70.0
# Question that most people skip: 3 - 4 - 0.15, 5 - 4 - 0.10, 23 - 4 - 0.20
# Question that most people answer incorrectly: 8 - 20 - 0.15, 18 - 20 - 0.90
# Result file 'class1_grades.txt' created successfully.
